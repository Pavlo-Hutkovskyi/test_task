# %% [markdown]
# ###### 1. Import regular expressions for text processing
# ###### 2. Import pandas for data manipulation
# ###### 3. Import abstract syntax tree for safely evaluating strings

# %%
import re
import pandas as pd
import ast

# %% [markdown]
# ###### Read the CSV file containing the dataset with markup and convert the 'marker' column from string representation of lists to actual lists

# %%
df = pd.read_csv('data/mountain_dataset_with_markup.csv')
df['marker'] = df['marker'].apply(ast.literal_eval)

# %% [markdown]
#  ###### Function to tag words in a sentence based on given markers for mountain names

# %%
def tag_sentence_corrected(sentence, markers):
    print(sentence)
    words = re.findall(r"(?:#\w+|St\.|\b\w+(?:'\w+)?|\d+\.\w+|[.,!?;:])", sentence)
    tags = ['O'] * len(words)

    if len(markers) != 0:
        for marker in markers:
            mount_names = str(sentence[marker[0]:marker[1]]).split()
            if len(mount_names) == 1:
                tags[words.index(mount_names[0])] = 'B-MOUNTAIN'
            else:
                for i in range(len(mount_names)):
                    if i == 0:
                        tags[words.index(mount_names[i])] = 'B-MOUNTAIN'
                    else:
                        tags[words.index(mount_names[i])] = 'I-MOUNTAIN'
            print(words)
            print(tags)
    return words, tags

# %%
tokens_list = []
ner_tags_list = []

# %% [markdown]
# ###### Iterate through each row in the DataFrame and process each sentence to extract words and tags

# %%
for index, row in df.iterrows():
    words, tags = tag_sentence_corrected(row['text'], row['marker'])
    tokens_list.append(words)
    ner_tags_list.append(tags)
# Out:
# A visit to a science museum for hands-on learning.
# Voice surface coach set democratic time year. Evidence movie successful Congress this various into. Name around hair especially.
# Parent according maybe activity activity finish. Within skill raise surface discuss. Series kitchen Congress rather he.
# A visit to a sculpture garden with intriguing artworks.
# The Julian Alps in Slovenia offer pristine lakes and picturesque landscapes.
# ['The', 'Julian', 'Alps', 'in', 'Slovenia', 'offer', 'pristine', 'lakes', 'and', 'picturesque', 'landscapes', '.']
# ['O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The referee blows the whistle, signaling the end of the first half. The score is tied at 1-1.
# Again eat owner drop. Stay recognize none size effort agency.
# Set large fight speech local. Individual if nation buy movie road crime.
# Important nearly themselves particular sort close case. Positive success total fund.
# Wonder behind everybody dream. Owner much analysis common various already fly. Child mother manage power purpose truth bag side.
# Phone station white leave image.
# Seem Mrs bed hand tend relate. Myself home might significant right customer. Indicate special protect ready.
# Ten be ten cover use meeting. Season indeed section almost maintain hope religious.
# Myself he ago back. Top wide nice together quality.
# Manage trade stand site fund administration. Consumer response difference work tonight us much. Significant person many through heart young.
# Care energy fast almost player source. When vote put politics other forget bring.
# The Dolomites in Italy are famous for their unique limestone formations.
# ['The', 'Dolomites', 'in', 'Italy', 'are', 'famous', 'for', 'their', 'unique', 'limestone', 'formations', '.']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Civil film yet turn top. Event structure concern or. I majority long yes behind accept land.
# Whether cost such begin. Mind well east deep.
# A visit to an astronomy observatory for stargazing.
# Small share Congress study standard issue set. Respond lot condition home.
# Career forget too wrong similar address. Quickly stage fill. Decide sense contain describe how computer.
# Fear hour but president. Plan professional show industry public may glass.
# Sampling local coffee shops and their unique brews.
# Listening to a live band at an open-air concert.
# Feeling the tranquility and serenity of the Andes Mountains #naturelover #mountainscape
# ['Feeling', 'the', 'tranquility', 'and', 'serenity', 'of', 'the', 'Andes', 'Mountains', '#naturelover', '#mountainscape']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O']
# The Carpathian Mountains are a vital part of Europe's natural heritage.
# ['The', 'Carpathian', 'Mountains', 'are', 'a', 'vital', 'part', 'of', "Europe's", 'natural', 'heritage', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# A day of exploring a historic cemetery with notable graves.
# Company fund must. Central pick budget so.
# Respond tax force. Business marriage air left room assume fish.
# Opportunity will be everybody particular team be. South several action report raise.
# Just enough capital politics professor however consider top. Take throughout theory join learn hospital the.
# Range history six local. World room time ago.
# Lay down result administration. Baby provide choice news blood yeah.
# I explored the Tatra Mountains, a beautiful range in Slovakia.
# ['I', 'explored', 'the', 'Tatra', 'Mountains', ',', 'a', 'beautiful', 'range', 'in', 'Slovakia', '.']
# ['O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Read leave nothing employee sport. Sister finish theory season onto.
# Reason notice plant brother write.
# The Blue Ridge Mountains in Virginia are known for their scenic beauty.
# ['The', 'Blue', 'Ridge', 'Mountains', 'in', 'Virginia', 'are', 'known', 'for', 'their', 'scenic', 'beauty', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# I visited a wildlife sanctuary and observed the animals.
# Feeling the serenity of the Swiss Alps, a paradise for nature lovers and hikers #swissalps #mountainparadise
# ['Feeling', 'the', 'serenity', 'of', 'the', 'Swiss', 'Alps', ',', 'a', 'paradise', 'for', 'nature', 'lovers', 'and', 'hikers', '#swissalps', '#mountainparadise']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Teacher good small short. Here must director return. Plant specific ten top beautiful into.
# She fly model player suddenly soon important. Market should mouth return any read the vote.
# Describe employee five operation. Else operation break hope. Newspaper hair just yourself.
# Especially glass make certainly half lose any. Challenge husband operation subject.
# The Andes Mountains are a vast mountain range that runs along the western coast of South America. #andesmountains #southamericatravel
# ['The', 'Andes', 'Mountains', 'are', 'a', 'vast', 'mountain', 'range', 'that', 'runs', 'along', 'the', 'western', 'coast', 'of', 'South', 'America', '.', '#andesmountains', '#southamericatravel']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# A day of exploring a scenic canyon with towering cliffs.
# The Tian Shan Mountains are a critical water source for Central Asia.
# ['The', 'Tian', 'Shan', 'Mountains', 'are', 'a', 'critical', 'water', 'source', 'for', 'Central', 'Asia', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# I went to a jazz concert and enjoyed the soulful music.
# Break animal west herself same apply. Program contain baby case small. Impact party fact up.
# The Appalachian Mountains are known for their rich biodiversity.
# ['The', 'Appalachian', 'Mountains', 'are', 'known', 'for', 'their', 'rich', 'biodiversity', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Positive picture test soon sell throw. Majority charge collection education site over. Off main nation thing. Similar guess cut job recently add.
# Another size officer may over contain. Bill great how far entire soldier. First buy personal expert lay.
# Exploring a canyon trail with towering rock formations.
# Cell either control. Subject fire painting establish husband.
# Another knowledge tough. Season place animal career special.
# Letter real none through media agreement whose. Site follow just inside happen watch over member. Probably measure possible management choice.
# Knowledge company become news collection capital. Small once item education.
# Ever exist develop. Note figure note could natural. Science able find high. Big build image they.
# Particularly middle play past meet force want piece. Deal second yourself activity. Each two industry provide.
# A painting workshop to unleash creativity on canvas.
# Listening to live punk rock music at an underground club.
# Fly though side break white mention. House window sign surface it.
# Sell card son toward fund. Wall side place production.
# Million toward read similar right international. Economic quite become smile note environment.
# Sampling different types of craft beer at a brewery tour.
# Matter community explain personal. Reality save assume hit say wrong service.
# Find serenity amidst the towering peaks of the Swiss Alps, a paradise for nature lovers and hikers seeking tranquility. #swissalps #mountainretreat
# ['Find', 'serenity', 'amidst', 'the', 'towering', 'peaks', 'of', 'the', 'Swiss', 'Alps', ',', 'a', 'paradise', 'for', 'nature', 'lovers', 'and', 'hikers', 'seeking', 'tranquility', '.', '#swissalps', '#mountainretreat']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Establish audience pattern visit skin defense behavior. Drop ever police information without. Boy reduce seven.
# Attending a poetry reading and appreciating the spoken word.
# The Renaissance period marked a cultural rebirth in Europe, with advancements in art, science, and literature.
# Exploring the hidden valleys and rugged peaks of the Andes Mountains #southamericatrails #mountainexplorer
# ['Exploring', 'the', 'hidden', 'valleys', 'and', 'rugged', 'peaks', 'of', 'the', 'Andes', 'Mountains', '#southamericatrails', '#mountainexplorer']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O']
# A visit to a cultural center with art exhibitions.
# Democrat rest do right. Yet become join end. Improve guy rest information ever Mr.
# House long today analysis. Ahead task TV take include activity national.
# Art finish evidence worker agreement try.
# Glass summer part attention determine. Wear leave myself.
# Group course wait because act. Light exactly you. Strategy interview their strategy.
# Trying out a new dance style like salsa or tango.
# The Andes run through several South American countries.
# ['The', 'Andes', 'run', 'through', 'several', 'South', 'American', 'countries', '.']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Many stuff station stuff. Consider interview large tell. School imagine show ground within develop. Cost under value week.
# Trying out a new fitness class like yoga or pilates.
# Try should nice audience. Possible off enjoy way.
# Some wish gun down range huge fly. Lawyer election would.
# Partner sport measure last sound church road. Miss thought third other commercial today affect.
# Then of top marriage lay maintain interest.
# The Pyrenees form a natural border between France and Spain.
# Per certainly event news care. Quite build fear effort cover. Activity respond shoulder economy continue various.
# Sampling street food at a multicultural food festival.
# I spent the day at a spa for some self-care.
# For book them worker close professional field. So win every effect side.
# Report pattern often media.
# Wall local rise serve each. Perhaps part reduce scene instead class. Choose believe just maintain himself those price.
# A day of exploring a desert oasis with palm trees.
# Final act pick shake myself north son. Around case travel decade skin.
# Bag mission hundred. Friend concern movement let.
# Image raise quite anyone region. Cup indicate month possible cost ten wish realize. Manage official word they. Box both majority place almost.
# Particular there than. Help treat small detail look she. Need prepare contain one matter do. Everybody recent civil lot sea really idea.
# The Kunlun Mountains separate the Tibetan Plateau from the Tarim Basin.
# ['The', 'Kunlun', 'Mountains', 'separate', 'the', 'Tibetan', 'Plateau', 'from', 'the', 'Tarim', 'Basin', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The Alps are a major mountain range in Europe.
# ['The', 'Alps', 'are', 'a', 'major', 'mountain', 'range', 'in', 'Europe', '.']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The city skyline looked beautiful at sunset.
# A weekend road trip to a scenic coastal lighthouse.
# Exploring a riverfront market with local produce and crafts.
# A visit to a riverside park with scenic views.
# Term soon list determine. Discussion center your mean now ground.
# Standing in awe of the majestic Mount Everest, the highest mountain on Earth, and feel the humbling power of nature's grandeur. #mountainchallenge #everestdreams
# ['Standing', 'in', 'awe', 'of', 'the', 'majestic', 'Mount', 'Everest', ',', 'the', 'highest', 'mountain', 'on', 'Earth', ',', 'and', 'feel', 'the', 'humbling', 'power', 'of', "nature's", 'grandeur', '.', '#mountainchallenge', '#everestdreams']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Gas mind drive sell figure available.
# I hiked in the Dolomite Mountains, known for their unique rock formations.
# ['I', 'hiked', 'in', 'the', 'Dolomite', 'Mountains', ',', 'known', 'for', 'their', 'unique', 'rock', 'formations', '.']
# ['O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The Kunlun Mountains are part of the vast Tibetan Plateau.
# ['The', 'Kunlun', 'Mountains', 'are', 'part', 'of', 'the', 'vast', 'Tibetan', 'Plateau', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Run here it tax inside. Make how phone allow consider hit.
# Our hope have receive. End little behavior again several force especially.
# A visit to a planetarium to learn about the cosmos.
# Venture into the hidden trails and breathtaking vistas of the Andes Mountains, a South American treasure trove of natural beauty. #southamericatravel #mountainexplorer
# ['Venture', 'into', 'the', 'hidden', 'trails', 'and', 'breathtaking', 'vistas', 'of', 'the', 'Andes', 'Mountains', ',', 'a', 'South', 'American', 'treasure', 'trove', 'of', 'natural', 'beauty', '.', '#southamericatravel', '#mountainexplorer']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Lawyer best through. Attack eye personal behavior center memory.
# Significant wall treat. Second will relationship size forward leader.
# Minute technology fill structure group. Common human conference second himself.
# Cut child team couple politics any physical. Involve turn new federal what sport free speech.
# Range artist produce group citizen issue large. Only middle specific.
# Point day relate chair. Quite another thought everyone.
# Open long investment where simply dark apply candidate. Action level until human right into. Special water brother dog side.
# Poor voice represent ball. Simply wear number tough significant.
# Air responsibility within personal. Take try outside prevent of per seem.
# The Swiss Alps are a popular destination for winter sports.
# ['The', 'Swiss', 'Alps', 'are', 'a', 'popular', 'destination', 'for', 'winter', 'sports', '.']
# ['O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Cooking experiments in the kitchen lead to discovering new recipes and culinary delights.
# A weekend getaway to a bed and breakfast in the countryside.
# Because population consider forget suffer partner. Ask consider amount lay idea building.
# Top party finish choose. Five loss kitchen accept student do soon. Build available however Republican claim mean tell.
# Mount McKinley, now officially called Denali, is the tallest peak in North America.
# ['Mount', 'McKinley', ',', 'now', 'officially', 'called', 'Denali', ',', 'is', 'the', 'tallest', 'peak', 'in', 'North', 'America', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The Rwenzori Mountains are sometimes referred to as the 'Mountains of the Moon'.
# ['The', 'Rwenzori', 'Mountains', 'are', 'sometimes', 'referred', 'to', 'as', 'the', 'Mountains', 'of', 'the', 'Moon', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The Rocky Mountains offer a rugged and challenging wilderness experience for those who seek it. #mountainadventures #coloradotrails
# ['The', 'Rocky', 'Mountains', 'offer', 'a', 'rugged', 'and', 'challenging', 'wilderness', 'experience', 'for', 'those', 'who', 'seek', 'it', '.', '#mountainadventures', '#coloradotrails']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Mount Everest is a challenging climb, but the rewards are worth it. #mountainclimbing #everestchallenge
# ['Mount', 'Everest', 'is', 'a', 'challenging', 'climb', ',', 'but', 'the', 'rewards', 'are', 'worth', 'it', '.', '#mountainclimbing', '#everestchallenge']
# ['B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Lose fact certain. Mouth buy three whole nothing summer.
# A painting class with a focus on abstract art.
# Painting trouble visit century figure subject street. Mind growth four also have road approach need. Amount sound every.
# Responsibility within name down turn late measure. Eye within green material.
# Energy stop big baby amount. Respond society something common speak.
# The Cascade Range extends from British Columbia to California.
# ['The', 'Cascade', 'Range', 'extends', 'from', 'British', 'Columbia', 'to', 'California', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# I explored a historic district and learned about its heritage.
# Embark on an adventure to the majestic peaks of the Himalayas, where spirituality and nature intertwine. #himalayanadventure #mountainspirit
# ['Embark', 'on', 'an', 'adventure', 'to', 'the', 'majestic', 'peaks', 'of', 'the', 'Himalayas', ',', 'where', 'spirituality', 'and', 'nature', 'intertwine', '.', '#himalayanadventure', '#mountainspirit']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Along magazine agree sort heavy central. Avoid thing through election nor Congress.
# Mrs buy into every offer crime.
# Tv service after give. Break future nature mention mention. Mention dog pressure wait because share side.
# Mr team cultural fear store. Few entire site future.
# Issue analysis network.
# Spend could imagine save. Anything any live spring your always father. Manage common maintain cause on push.
# Edge product avoid everyone. Live particular issue board list about.
# Stay safe pattern. Issue community although south production message.
# Travel box hour turn should administration. Gas not story bank yes.
# Individual perhaps trade major large course nothing.
# A day at the beach is a perfect way to relax.
# I climbed Mount Eiger in the Swiss Alps, a challenging and rewarding experience.
# ['I', 'climbed', 'Mount', 'Eiger', 'in', 'the', 'Swiss', 'Alps', ',', 'a', 'challenging', 'and', 'rewarding', 'experience', '.']
# ['O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# ['I', 'climbed', 'Mount', 'Eiger', 'in', 'the', 'Swiss', 'Alps', ',', 'a', 'challenging', 'and', 'rewarding', 'experience', '.']
# ['O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Change right high campaign laugh maintain. Data land increase bank age woman eight.
# Beat cup leave fish for. Source western exactly their hundred. Power figure reveal commercial technology site always. Owner control draw hold score.
# For report call detail. Ground structure upon. May Mr kind tonight ten unit read change.
# Edge throughout respond candidate choose attention little. Itself science value wrong.
# Red north money star prevent box truth. Against official sometimes marriage TV very whole. Idea head back its poor administration spend.
# Exploring a river canyon with rushing waters.
# Over reality issue people score camera mean Congress. Design show tree require those can. Sport issue gun ready.
# My put may. After notice while this camera sense.
# I enjoyed a relaxing vacation by the beach.
# Exploring a mountain resort with outdoor activities.
# Computer try nothing piece artist step poor member. No from notice practice east music.
# A visit to a cultural institute with art installations.
# A visit to a historic cathedral with impressive architecture.
# Visiting art galleries is a cultural indulgence.
# Away shoulder professor cell science. Security right instead option structure level.
# Walk cover cover mouth miss. Hand often heavy language.
# Experience the thrill of whitewater rafting through the canyons of the Taurus Mountains, where adventure awaits amidst majestic peaks. #adventureseeker #mountainrivers
# ['Experience', 'the', 'thrill', 'of', 'whitewater', 'rafting', 'through', 'the', 'canyons', 'of', 'the', 'Taurus', 'Mountains', ',', 'where', 'adventure', 'awaits', 'amidst', 'majestic', 'peaks', '.', '#adventureseeker', '#mountainrivers']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Trying out a new workout routine at a fitness studio.
# Which consider partner respond. Research music myself model always.
# Real smile green own. Himself forget change agency sister interview.
# Unit everyone phone community right herself year. Day happen rule although. Late best personal play usually.
# The Southern Alps are a mountain range in New Zealand.
# ['The', 'Southern', 'Alps', 'are', 'a', 'mountain', 'range', 'in', 'New', 'Zealand', '.']
# ['O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Want toward before. View class between analysis.
# Sea different appear walk. Series policy always how check physical.
# Particularly tell not section southern suffer. Figure rise close piece want in nature.
# Exploring a historic town immersed me in its rich history.
# Three table gun certainly institution discuss cause would. Per several possible he.
# Difficult whether hundred require number myself edge heart. Issue program month these customer six. Common pay station necessary various.
# Voice control local wife consider film. Form lay forget represent according age land.
# Business generation analysis necessary. Treatment animal business thus fact data.
# Traditional five call necessary fire. Community much house vote thank. Scientist item game a west wide.
# Maybe individual born heavy. Suffer early during father during modern computer.
# Daughter dinner bill model sure allow. Might cut standard up.
# The Himalayas, with their snow-capped peaks, are a source of major rivers in Asia.
# ['The', 'Himalayas', ',', 'with', 'their', 'snow', 'capped', 'peaks', ',', 'are', 'a', 'source', 'of', 'major', 'rivers', 'in', 'Asia', '.']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Save direction a ok development environment administration. Require effect together concern including.
# A movie night with friends is always a fun time.
# Not him Mrs idea sometimes. Forget defense animal.
# The Tian Shan Mountains in Kyrgyzstan offer opportunities for trekking and mountaineering.
# ['The', 'Tian', 'Shan', 'Mountains', 'in', 'Kyrgyzstan', 'offer', 'opportunities', 'for', 'trekking', 'and', 'mountaineering', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Apply character all purpose sense. Finally together director must during anyone dinner. Away bill budget society someone indicate.
# Mind rather large beat. Within reflect yet expert maybe be.
# Age them attention central garden throughout. Natural federal back another.
# Planning a vacation? I'm thinking of going to the beach for some relaxation.
# Trying out a new workout class like kickboxing or spinning.
# Exploring a riverwalk and enjoying the waterfront.
# Speech perhaps figure who. Live together idea throw able parent six. Future sing fight course mouth country theory right.
# No term fine your PM less economy turn. Agency book great product individual foot financial.
# Director themselves there back exactly happy explain. Authority watch discussion development different debate kitchen. Phone example color memory.
# Fish look director read share doctor show. Plant him field.
# Recognize beyond quite class someone. Sort during bring quickly. Away charge customer indeed front.
# Maintain open store out couple measure. Share possible lose these blue center.
# Several factor because bed decision.
# Level wall kind environmental machine religious. Available affect happen mean.
# Wall top doctor reflect.
# Animal same practice perhaps note alone subject.
# Quickly rest tend adult million. Mind treat measure these. Red word option too even sort.
# Paper fill one remain consider seem drop. Church exactly issue suddenly send strong sense keep.
# Stage end support place. Have exactly daughter.
# Politics contain manage effort surface value. Feeling analysis defense land last glass.
# Attending a comedy club is a guaranteed good time.
# The Tien Shan Mountains are home to diverse flora and fauna.
# ['The', 'Tien', 'Shan', 'Mountains', 'are', 'home', 'to', 'diverse', 'flora', 'and', 'fauna', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Religious perform boy. Ten street price group professor various case. Nature current generation despite relate race near.
# Term figure opportunity into. Onto sort heavy beat. Final explain cell national how these of.
# Somebody more exactly woman year.
# Team space officer make cover. Brother per majority any strategy body. Scene because green college.
# All in marriage wish professor. Assume science probably show coach claim.
# Avoid guess little newspaper. Break eye word agreement risk line area.
# Social position increase. Model attack six political high she. That then around sure respond bank.
# Name time professor. Have four finally them bank identify be crime. On item low.
# The Alps, with their towering peaks, are a major mountain range in Europe.
# ['The', 'Alps', ',', 'with', 'their', 'towering', 'peaks', ',', 'are', 'a', 'major', 'mountain', 'range', 'in', 'Europe', '.']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Feeling the spiritual connection to the sacred mountains of the Himalayas, where meditation and nature intertwine. #indiaadventure #mountainspirit
# ['Feeling', 'the', 'spiritual', 'connection', 'to', 'the', 'sacred', 'mountains', 'of', 'the', 'Himalayas', ',', 'where', 'meditation', 'and', 'nature', 'intertwine', '.', '#indiaadventure', '#mountainspirit']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Experiencing the thrill of skiing down the slopes of the Alps, the highest and longest mountain range in Europe #skiinglife #mountainadventures
# ['Experiencing', 'the', 'thrill', 'of', 'skiing', 'down', 'the', 'slopes', 'of', 'the', 'Alps', ',', 'the', 'highest', 'and', 'longest', 'mountain', 'range', 'in', 'Europe', '#skiinglife', '#mountainadventures']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# K2 is the second-highest mountain on Earth.
# ['K2', 'is', 'the', 'second', 'highest', 'mountain', 'on', 'Earth', '.']
# ['B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Sampling local street food is a culinary adventure.
# Have wish military receive black final here. Old himself eye pattern hotel about woman perform. Able mouth world approach.
# Better share knowledge sea stock grow. Billion record no. Outside subject population in old. East majority question case.
# Likely offer pass member pass. Bag business carry nice respond.
# Anyone shoulder shoulder huge run themselves. Both old per method theory.
# Trying out a new hobby like pottery was both fun and challenging.
# Safe get send floor shoulder within media. Bed hour receive.
# His performance certain huge tend.
# Prepare where its adult second enter. Perhaps tend sometimes receive professor. Two score subject throughout them.
# Participant suffer authority wear service to power. Worker store quality benefit.
# Nearly whole thing thought along opportunity. Training time home before. Truth fund successful its remember his page card.
# Road physical let issue program issue movement.
# Man wife speech administration discussion of test. Leader instead myself development exactly new.
# Sign threat address theory very this cold. Simple official hit game.
# Democratic administration lawyer war a. Several wind account chair. Front also green front public run.
# Than during investment position inside attention buy east. Special hour act million. Help know view kind identify.
# Why don't scientists trust atoms? Because they make up everything!
# Balancing work and leisure is essential for maintaining a healthy and fulfilling lifestyle.
# Maintain above form yeah individual focus. Hotel special difficult across car manager simply. Report prepare white meet message project behavior.
# Each class participant institution outside age. Federal painting forget although than natural. All surface not buy list investment conference.
# Girl order couple first finish above including. Trouble manage country employee.
# How was your day? Mine was quite busy with work and meetings.
# Style officer him sort onto. Forward need day happy inside control.
# Rise concern Mr plan analysis give deep. Certainly right together member government parent. Tonight provide exist decide itself summer.
# Way small seven various dark. Help until large anything government strategy key.
# I explored a historic castle and learned about its history.
# Trek through the lush rainforests and volcanic landscapes of the Andes Mountains, where nature's diversity unfolds at every step. #southamericatravel #mountainparadise
# ['Trek', 'through', 'the', 'lush', 'rainforests', 'and', 'volcanic', 'landscapes', 'of', 'the', 'Andes', 'Mountains', ',', 'where', "nature's", 'diversity', 'unfolds', 'at', 'every', 'step', '.', '#southamericatravel', '#mountainparadise']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# A weekend retreat at a mountain lodge for tranquility.
# Enchanted by the serene beauty of the Swiss Alps! #mountainmagic #swissalps
# ['Enchanted', 'by', 'the', 'serene', 'beauty', 'of', 'the', 'Swiss', 'Alps', '!', '#mountainmagic', '#swissalps']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O']
# Use lead system offer author. Out six dream and clearly. Another off system first tell choice memory scientist. Lead able face federal.
# Space put think. Concern actually add parent. Whom than join environment parent month.
# The Rhodope Mountains are a hidden gem in Bulgaria, with lush forests, pristine lakes, and charming villages. #bulgariannature #rhodopemountains
# ['The', 'Rhodope', 'Mountains', 'are', 'a', 'hidden', 'gem', 'in', 'Bulgaria', ',', 'with', 'lush', 'forests', ',', 'pristine', 'lakes', ',', 'and', 'charming', 'villages', '.', '#bulgariannature', '#rhodopemountains']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Red the serious skin. Machine wear move scene attack stage. Sense compare course doctor clearly doctor choose.
# Strategy pick do. Still sense place specific they popular accept.
# Day your them investment card. Chance strategy institution have sea.
# Today vote on nice attorney kitchen someone. Middle close audience hour.
# Sampling different varieties of chocolate at a chocolate festival.
# The Brooks Range is the northernmost mountain range in North America.
# ['The', 'Brooks', 'Range', 'is', 'the', 'northernmost', 'mountain', 'range', 'in', 'North', 'America', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Today between less among task recognize. Finally stock light power true.
# Than where to carry. Understand way within whom. Suddenly least director.
# Fight audience ground science. Industry explain purpose figure series trouble card treatment. Success change different anyone.
# I explored the Tatra Mountains in Slovakia, a haven for nature lovers.
# ['I', 'explored', 'the', 'Tatra', 'Mountains', 'in', 'Slovakia', ',', 'a', 'haven', 'for', 'nature', 'lovers', '.']
# ['O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Trying out a new outdoor activity like zip-lining or rock climbing.
# A visit to an outdoor market for fresh produce.
# Water participant particular tough perform mean much.
# Play anyone among rest identify. Material view coach heart religious feel.
# Believe likely sit him scene soldier.
# Keep green worry father sea well project. Him culture room. Say war herself single bill plan collection wrong.
# Inside financial five top. Particular new then.
# Risk particularly by. Account firm economic away in quickly. Into discussion history.
# No expect together whom quickly central whom.
# Explain according course give evidence. Product win camera executive more magazine feel. It food spring television standard.
# Stay fast nothing high look. Bill appear theory nothing accept.
# Address when baby hold use effort sure. Save quality major could site look.
# Civil health wife recognize. Reality very kitchen create house against.
# Embark on an unforgettable journey through the rugged terrain of the Appalachian Mountains, a North American hiking haven. #hikingtrail #mountainescape
# ['Embark', 'on', 'an', 'unforgettable', 'journey', 'through', 'the', 'rugged', 'terrain', 'of', 'the', 'Appalachian', 'Mountains', ',', 'a', 'North', 'American', 'hiking', 'haven', '.', '#hikingtrail', '#mountainescape']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# I took a pottery workshop and created handmade ceramics.
# The Himalayas, home to diverse ecosystems, from tropical rainforests to alpine meadows, showcase nature's symphony of wonders. #mountaindiversity #himalayanexpedition
# ['The', 'Himalayas', ',', 'home', 'to', 'diverse', 'ecosystems', ',', 'from', 'tropical', 'rainforests', 'to', 'alpine', 'meadows', ',', 'showcase', "nature's", 'symphony', 'of', 'wonders', '.', '#mountaindiversity', '#himalayanexpedition']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Witness the awe-inspiring beauty of Mount Fuji, Japan's sacred icon, and feel the spiritual connection to its majestic presence. #japaneseculture #mountainmagic
# ['Witness', 'the', 'awe', 'inspiring', 'beauty', 'of', 'Mount', 'Fuji', ',', "Japan's", 'sacred', 'icon', ',', 'and', 'feel', 'the', 'spiritual', 'connection', 'to', 'its', 'majestic', 'presence', '.', '#japaneseculture', '#mountainmagic']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Real control across exactly. Financial little special final worry.
# Mount Rainier is a popular destination for photography, with stunning views of the mountain and surrounding area. #washingtonwonders #mountainviews
# ['Mount', 'Rainier', 'is', 'a', 'popular', 'destination', 'for', 'photography', ',', 'with', 'stunning', 'views', 'of', 'the', 'mountain', 'and', 'surrounding', 'area', '.', '#washingtonwonders', '#mountainviews']
# ['B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# The Rhodope Mountains in Bulgaria are a haven for biodiversity and hiking enthusiasts.
# ['The', 'Rhodope', 'Mountains', 'in', 'Bulgaria', 'are', 'a', 'haven', 'for', 'biodiversity', 'and', 'hiking', 'enthusiasts', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Attending a local food and wine festival for culinary delights.
# Watch arm fly design skin upon. Adult later available man dream memory single parent. Effort bill walk.
# Trekking through the lush rainforests and volcanic landscapes of the Andes Mountains, where nature's diversity unfolds at every step. #ecuadortravel #mountainadventures
# ['Trekking', 'through', 'the', 'lush', 'rainforests', 'and', 'volcanic', 'landscapes', 'of', 'the', 'Andes', 'Mountains', ',', 'where', "nature's", 'diversity', 'unfolds', 'at', 'every', 'step', '.', '#ecuadortravel', '#mountainadventures']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Color claim describe fill teach executive structure grow. Sport third already series man suffer difference.
# I spent the weekend exploring a local park.
# Cruising along the Mediterranean coast, each port of call offered a unique cultural experience.
# Camping under the stars is a peaceful retreat.
# Send wear person lead Democrat.
# Try TV street build. Soon produce almost movie growth well. Resource participant however maybe case part move.
# Throw present magazine three enough resource business. Final personal more at final.
# Reach carry detail discuss. Suggest inside sort thought. Assume three party operation peace also Democrat reality.
# Spring push each realize real. History add scene them.
# Fast writer these turn this summer. Mean half usually hospital interview interesting.
# Embracing the challenge and reward of hiking the Rocky Mountains #mountainfitness #coloradotrails
# ['Embracing', 'the', 'challenge', 'and', 'reward', 'of', 'hiking', 'the', 'Rocky', 'Mountains', '#mountainfitness', '#coloradotrails']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O']
# I spent a day at an amusement park, enjoying the rides.
# Finding peace and tranquility amidst the towering peaks of the Sierra Nevada Mountains #californiatrails #mountainretreat
# A visit to a cultural heritage site with ancient ruins.
# Old begin room. Eye sense city society opportunity Mr.
# I enjoyed the breathtaking views of the Sierra Nevada mountains in California.
# ['I', 'enjoyed', 'the', 'breathtaking', 'views', 'of', 'the', 'Sierra', 'Nevada', 'mountains', 'in', 'California', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O']
# I told my wife she should embrace her mistakes. She gave me a hug.
# Also involve whom yet. Everybody ability total in save manager. Hold information fast safe product. Beat here event kind far suddenly store.
# Trying out a dance class for a fun and energetic workout.
# Simple become push entire phone stage key hope. Pressure question very position. Create woman ready employee drop call.
# A day of exploring a vibrant city neighborhood.
# Management walk government short lawyer interesting election. Fast yard thing. Miss fear available bit itself democratic exactly.
# The slopes of the Alps beckon skiers and snowboarders to experience the thrill of gliding down snow-covered peaks. #skiinglife #mountainadventures
# ['The', 'slopes', 'of', 'the', 'Alps', 'beckon', 'skiers', 'and', 'snowboarders', 'to', 'experience', 'the', 'thrill', 'of', 'gliding', 'down', 'snow', 'covered', 'peaks', '.', '#skiinglife', '#mountainadventures']
# ['O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Attending cultural events broadens my perspective.
# Embracing the challenge of climbing the iconic Mount Kilimanjaro, the highest mountain in Africa #mountainclimbing #africanadventures
# ['Embracing', 'the', 'challenge', 'of', 'climbing', 'the', 'iconic', 'Mount', 'Kilimanjaro', ',', 'the', 'highest', 'mountain', 'in', 'Africa', '#mountainclimbing', '#africanadventures']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Mrs body on foot to. Education allow that response certain may.
# Nice commercial enter. Special against bring star bring name.
# World far while who. Ready cause building specific kid pretty. Play enjoy player list after long.
# Key authority chance late speak. Manager radio stage it court room.
# Table miss cold table wait green example. World compare throughout father of. Order give range very age even teach.
# Move cultural write these lead detail.
# Reveal fly him rich. Sister party gun fast here source. Here top money environmental.
# Mount Kilimanjaro is the highest peak in Africa and a popular climbing destination.
# ['Mount', 'Kilimanjaro', 'is', 'the', 'highest', 'peak', 'in', 'Africa', 'and', 'a', 'popular', 'climbing', 'destination', '.']
# ['B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Even window success participant major task.
# I love skiing in the Japanese Alps during the winter.
# ['I', 'love', 'skiing', 'in', 'the', 'Japanese', 'Alps', 'during', 'the', 'winter', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O']
# Reach range husband cut let. Nice case send necessary make. Next sea draw TV.
# And education prove player money race own. Kind conference this different bar huge hold.
# Mount Kilimanjaro is a popular destination for climbers.
# ['Mount', 'Kilimanjaro', 'is', 'a', 'popular', 'destination', 'for', 'climbers', '.']
# ['B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Wide whether relate standard authority. Body explain safe upon. Special drive conference right hour common determine. Tell laugh program only.
# Born happy style rest my care.
# Direction report keep property size feel animal meet.
# Just provide professor notice hold town.
# A day of volunteering at a local community center.
# I explored a new neighborhood over the weekend.
# Catch debate new pretty. Dream seat research according week throw.
# May show painting radio family down. Feeling say north team cultural police. Treat clear newspaper owner street resource.
# White know card site subject. Open about church available between. Task five into interest newspaper.
# Thus including owner one church region story. Important believe space community. Event tax experience issue enough condition major.
# Yard head loss face. That response hospital body it box guy.
# Continue bag food group. Run TV nearly wife four before. Billion current training exist.
# A weekend retreat at a riverside cottage for relaxation.
# Gun program beautiful house research ok resource. Else teacher them leave economic news return point. Sense bank southern field type.
# Follow language item around. Lot front body. Impact do situation information this over could evening.
# Key line major describe. Peace indicate thank song minute enough Mr.
# Anyone together accept. West side station tend score treatment although option.
# Financial husband will history prove within.
# Sit low drug avoid church contain. Cost international policy seat lose your person Mr.
# Him arm his investment poor write remember. Eight out he political leg.
# Serious group ready article. Between affect across mouth speak fire long.
# A day at the spa for pampering and relaxation.
# Two behind push activity south source per. Forward TV her change.
# Scene space decision training just. Outside career culture consumer.
# Window gun miss blood still onto beyond. Show front easy debate sign.
# About floor building remember case administration million. Last threat business message admit debate.
# If head administration already. Arrive Mr final concern card as must allow. Worker figure focus space large usually.
# Matter myself see everybody. Call mention really behavior building attention will spring. Answer cost pass piece.
# Attending a local science fair for interactive exhibits.
# Alone wish television direction who. Mr increase need read their camera happen us.
# The Swiss Alps are a popular destination for skiing and snowboarding, with world-class resorts and breathtaking views. #swissalps #skiinglife
# ['The', 'Swiss', 'Alps', 'are', 'a', 'popular', 'destination', 'for', 'skiing', 'and', 'snowboarding', ',', 'with', 'world', 'class', 'resorts', 'and', 'breathtaking', 'views', '.', '#swissalps', '#skiinglife']
# ['O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# A scenic drive through the mountains provided breathtaking views.
# Exploring a lakeside trail with serene water views.
# Rule fill detail choice participant whom everybody. Employee effect actually oil pretty. Sea marriage whom be.
# Including clear health dream never back green. Research six true conference. Kind let peace police get difference.
# Window bed medical.
# Soldier part best it spring painting or. Actually computer kid American.
# Short music agency.
# Human knowledge page know individual red. Music foreign research message two speak audience.
# Thus have return be much argue. Experience professional sea bar visit full.
# Gas important there different. Seem owner raise.
# Tonight act three out news factor. Small gun against people smile score fish sometimes.
# Risk star song student letter choice thus.
# Growth industry success floor institution high. Dream including tend kitchen discuss.
# Strolling through a museum and learning about history.
# Prevent learn bank pretty expect imagine would.
# Film kind century media after upon future. Blue agree clear.
# Less watch middle. Point piece return consumer.
# Color dark machine smile gun view. Smile although sing notice.
# Four huge purpose pick writer change.
# I attended a cooking class to improve my culinary skills.
# Body impact central affect good year. Leader learn agency analysis technology.
# Hair recently report young three southern them. Rock energy follow remain listen daughter she. Difference side man discover explain think.
# The Appalachian Mountains are a system of mountain ranges in the eastern United States.
# ['The', 'Appalachian', 'Mountains', 'are', 'a', 'system', 'of', 'mountain', 'ranges', 'in', 'the', 'eastern', 'United', 'States', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# See eye dark.
# Upon message shoulder new kind know. Create best lot continue to bad. Debate control seven next others.
# Shake cause institution job this fast. Someone threat reveal into ground ahead. War stock box.
# Feel man news. Cup southern oil local risk language send. Arm exactly stage of them. People however sell they life month.
# The Taurus Mountains are home to ancient ruins and historical sites, as well as stunning natural beauty. #turkeytravel #taurustrails
# ['The', 'Taurus', 'Mountains', 'are', 'home', 'to', 'ancient', 'ruins', 'and', 'historical', 'sites', ',', 'as', 'well', 'as', 'stunning', 'natural', 'beauty', '.', '#turkeytravel', '#taurustrails']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# A visit to a cultural museum with artifacts and exhibits.
# I climbed Mount Elbrus, the highest peak in Europe.
# ['I', 'climbed', 'Mount', 'Elbrus', ',', 'the', 'highest', 'peak', 'in', 'Europe', '.']
# ['O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Treat car forward herself. Out mission music alone hundred. Teacher east office we commercial. Couple what everybody people spring same only.
# I spent a weekend camping in the mountains.
# The Scandinavian Mountains are a mountain range in Northern Europe.
# ['The', 'Scandinavian', 'Mountains', 'are', 'a', 'mountain', 'range', 'in', 'Northern', 'Europe', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Make develop act which she structure. Worry continue upon science away.
# Listening to live blues music at a blues club.
# Much car instead news. Peace beyond new fill present program. Present out establish.
# Former push property others. Despite ok black war five word. Even manage smile ask.
# Strategy fly light rise star court whose. So player outside seem accept.
# Nature imagine impact term first environmental. Five relationship decade.
# Still popular magazine wide per at blue. Month build computer term reach practice green indicate.
# Finish might its travel court. Research concern responsibility movement pick foreign. Particularly protect nothing yourself since especially.
# Read crime executive book down. Clear nearly middle there he people. Six seat nearly cell easy game.
# Travel rise art can knowledge sell their. Smile town doctor family Mrs budget. Your building notice push important time. Ball truth at over say.
# Visit arrive edge attack entire sit seem. Care course boy growth. Once big year modern.
# Age really role why environment scene.
# Development race nothing add we part. Perhaps statement body someone own item.
# Most new while nothing you senior. Similar also easy ground along. Painting young would series report recent.
# International power enjoy conference sure small. Media or professor true.
# Religious left recognize baby wish can approach. Work decade pattern power member thus. Left drop ability might change.
# Majority very toward walk. Hotel last talk current.
# I skied in the Dolomites, a mountain range in Italy.
# ['I', 'skied', 'in', 'the', 'Dolomites', ',', 'a', 'mountain', 'range', 'in', 'Italy', '.']
# ['O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# I took a day trip to the countryside for some fresh air.
# Work station create under ball trouble. Garden enter why person lot drop. Cost ball within ahead defense program PM thing.
# The Scandinavian Mountains, also known as the Scandes, run through Norway and Sweden.
# ...
# The majestic peaks of the Himalayas inspire awe and wonder in all who see them. #mountainlover #himalayanhues
# ['The', 'majestic', 'peaks', 'of', 'the', 'Himalayas', 'inspire', 'awe', 'and', 'wonder', 'in', 'all', 'who', 'see', 'them', '.', '#mountainlover', '#himalayanhues']
# ['O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Camping under the starlit sky amidst the majestic Rocky Mountains #campinglife #mountainscapes
# ['Camping', 'under', 'the', 'starlit', 'sky', 'amidst', 'the', 'majestic', 'Rocky', 'Mountains', '#campinglife', '#mountainscapes']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O']
# Fish year long including begin on explain value. My those himself training memory.
# Mount Rainier is a dormant volcano that is a popular destination for hiking and camping. #washingtonstate #mountrainier
# ['Mount', 'Rainier', 'is', 'a', 'dormant', 'volcano', 'that', 'is', 'a', 'popular', 'destination', 'for', 'hiking', 'and', 'camping', '.', '#washingtonstate', '#mountrainier']
# ['B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Standing in awe of the majestic Mount Everest, the highest mountain on Earth #mountainchallenge #everestdreams
# ['Standing', 'in', 'awe', 'of', 'the', 'majestic', 'Mount', 'Everest', ',', 'the', 'highest', 'mountain', 'on', 'Earth', '#mountainchallenge', '#everestdreams']
# ['O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Station reflect each. Social type technology activity imagine claim.
# Trying out a new art class like pottery or sculpture.
# Hope probably your all rest sort light special. Site against the approach. Space follow sense business involve animal peace. Career reach seven.
# Message travel east memory option. Share part matter a perform middle remember.
# Ago property statement camera letter. Much face recent music bed.
# Moment song trade issue together. Top executive imagine think. Begin nature people indeed by serious. Soldier buy type.
# Among approach full. Bring defense return modern else.
# Read kitchen head mouth art Congress. None ground trade be party report concern. Rate store small myself have wish order.
# Certainly thing town ground. College arrive participant happen college throughout base. Serve determine let television.
# North factor interest. Once food professor those firm whose whatever others. Receive do TV artist economic.
# Firm good recently political skin hope. Message direction commercial east catch information certain. Although where full open trouble.
# A day of mountain biking on challenging trails.
# News attack throw nature great chair. Her win rather forward game tree.
# Bill issue blood memory whatever wall late. Suddenly lead budget environmental all speak every threat. Member begin sense house it suffer.
# Serve hundred base billion about. Else notice accept even avoid. Politics these indicate kid effort ahead.
# I spent the day at a spa for relaxation and rejuvenation.
# Gardening is a therapeutic hobby for me.
# Front character such. Program much answer main move section.
# Agreement entire produce agency service success. Read mean big day.
# Test pretty matter for stock should. Anything state analysis pick.
# Realize admit hospital hundred life anything. Method fine Democrat big. Able affect challenge idea though bill security.
# Indeed affect accept suffer decade seat discuss drive. Service specific speech forward.
# Base interview hour war. At avoid culture court.
# Bank same even on. Fly law will tax relate.
# Popular rich own top a forward. Goal reach third stage. Administration produce fight between.
# Rise own throw measure. Police public certain Republican yard. Another well bill leg she strong parent.
# Wife nor ten.
# Detail watch order affect. Not more red picture establish term. Prepare wait program successful fire two.
# I attended a poetry reading and was moved by the words.
# With heart score. Wonder ok treatment tree.
# Technology week defense stop. Around thousand I senior. Free military parent want professor fund.
# Task budget cell cost leave must into top. Address budget work. People great total stay successful no cut.
# Claim wrong set fact third great stage share. Reveal participant green relationship.
# After open mean central.
# Middle you apply yes per. Walk condition shoulder learn seek catch. Own hold art Mr each member child. Even bit bring somebody condition peace.
# A day at the beach with sand, sun, and waves.
# Get short such born natural trouble. Back physical end cup coach order. Less article subject not have.
# Politics dinner property pattern government.
# Fill local up draw turn each. Than drug exist mean stand probably once. Difference cut break response difficult rule especially.
# A weekend road trip to a charming mountain town.
# Public low ready. College who view two. Treatment likely debate dark.
# Continue any when think nature that fly. Wall even no seek.
# The Alps are home to many different cultures and traditions, making them a fascinating place to explore. #europetravel #alpslife
# ['The', 'Alps', 'are', 'home', 'to', 'many', 'different', 'cultures', 'and', 'traditions', ',', 'making', 'them', 'a', 'fascinating', 'place', 'to', 'explore', '.', '#europetravel', '#alpslife']
# ['O', 'B-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Guy father lawyer cultural father once baby. Return more time degree. Enough catch sound assume commercial article than.
# Believe since nation chair red middle thought unit. Add involve baby sort who. Attack hope suggest entire beat.
# Everybody claim beyond conference minute move son challenge. Television as list kitchen. Available value force here put recent.
# View none front to common head rate. Property forward best much occur production those.
# Lead soon painting shoulder. Item high so speech.
# Any use oil evidence figure respond network. Usually successful page improve strong almost. Her key purpose how summer.
# I only know 25 letters of the alphabet. I don't know y.
# I spent a weekend at a wellness retreat for relaxation and self-care.
# This have heart teach lot happy movement. Front every but firm poor project I attorney. Eat entire show word director buy crime.
# The Ural Mountains separate the European and Asian parts of Russia.
# ['The', 'Ural', 'Mountains', 'separate', 'the', 'European', 'and', 'Asian', 'parts', 'of', 'Russia', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Exploring a historic battlefield and its significance.
# Base staff we position. Political hard rich. Work heavy center put city officer.
# Head present now nor generation dark weight. Address work feel drop. Common summer green few yes win begin.
# About including movement base possible make per. Compare player everyone lay. Training mission need early.
# Risk beautiful similar century watch. Cell friend suddenly way return beyond watch. Image agency account case experience suddenly wall.
# Onto loss card onto. Center home also believe us.
# Subject where thing bring. Research book fast interesting cover. Order until rather find.
# I spent the day at an amusement park and had a blast.
# Money black catch safe. Say street movement billion two wish quickly.
# The Rwenzori Mountains are located on the border between Uganda and the Democratic Republic of the Congo.
# ['The', 'Rwenzori', 'Mountains', 'are', 'located', 'on', 'the', 'border', 'between', 'Uganda', 'and', 'the', 'Democratic', 'Republic', 'of', 'the', 'Congo', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Around air consumer itself street he success program. Everyone today accept trial. Price almost true so single especially.
# Sport red six Democrat writer sign. Factor where to name life. Structure ball western per interview forget.
# Feeling the spiritual connection to the sacred mountains of the Himalayas #indiaadventure #mountainspirit
# ['Feeling', 'the', 'spiritual', 'connection', 'to', 'the', 'sacred', 'mountains', 'of', 'the', 'Himalayas', '#indiaadventure', '#mountainspirit']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'O', 'O']
# Ascend to the summit of Mount Olympus, the mythical home of the Greek gods, and feel the power of legends. #mountainlegends #greecetravel
# ['Ascend', 'to', 'the', 'summit', 'of', 'Mount', 'Olympus', ',', 'the', 'mythical', 'home', 'of', 'the', 'Greek', 'gods', ',', 'and', 'feel', 'the', 'power', 'of', 'legends', '.', '#mountainlegends', '#greecetravel']
# ['O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Stuff my respond recently manager none. Let theory myself agency individual dinner. Concern many big really.
# Table type many experience cultural.
# Impact like blue research bar second. Line their enough glass mention energy sing.
# Onto why have opportunity. Long religious capital quickly wonder sure.
# Involve show group finally. Top him every market successful along. Pattern try miss behavior outside. Worker night red air him their.
# System can live stop. Civil present we play often lawyer various theory.
# The wish message camera still national stuff. Full water message other once theory month.
# Size ability several. Air rule pretty environmental gas. Check support TV impact beat happy.
# Indeed bad always analysis appear local. Few head plan issue pressure.
# Medical design evidence. Throughout bar know wish within safe.
# Exploring a desert landscape with unique sand formations.
# Cup yard need. Agree lead show rather event consider.
# Ready final eye local. Me others half account lead certain turn.
# Center against each woman than wait down. Morning break consumer let.
# Plan open who candidate number quality. Medical word break.
# Stand in awe of Mount Everest, the world's highest peak, and feel the humbling power of nature's grandeur. #mountainchallenge #everestdreams
# ['Stand', 'in', 'awe', 'of', 'Mount', 'Everest', ',', 'the', "world's", 'highest', 'peak', ',', 'and', 'feel', 'the', 'humbling', 'power', 'of', "nature's", 'grandeur', '.', '#mountainchallenge', '#everestdreams']
# ['O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Any front recent treatment baby. Right scientist take tree.
# A visit to an outdoor sculpture trail with contemporary artworks.
# Movie she under notice. Plan sing develop.
# Trial happen wonder glass spend sister can low. Traditional information ever small suggest.
# The development of renewable energy technologies is crucial for a sustainable future.
# A visit to an orchid garden with exotic blooms.
# Time back care my firm audience.
# Public ten point firm move bad happy. Morning find industry likely identify drop life major.
# Work candidate trouble sport. Future nothing six establish bill star always stand. Southern of blue off reduce rather allow.
# A visit to an architectural landmark with iconic design.
# Trying out a new instrument like guitar or piano.
# Discover hidden waterfalls and serene lakes nestled amidst the Rhodope Mountains, a Bulgarian treasure trove of natural beauty. #mountainretreat #bulgarianwonders
# ['Discover', 'hidden', 'waterfalls', 'and', 'serene', 'lakes', 'nestled', 'amidst', 'the', 'Rhodope', 'Mountains', ',', 'a', 'Bulgarian', 'treasure', 'trove', 'of', 'natural', 'beauty', '.', '#mountainretreat', '#bulgarianwonders']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Term push writer. Article race compare modern friend.
# Current board him. Own believe work lay myself.
# Treat not finally appear appear industry push. More give through grow stock.
# Performance risk nature all personal material.
# His ten idea indicate. Although sit then some pull next. High easy reduce particular test play.
# Occur tell garden though recent poor out. Power fight sometimes collection pull speak. Together address remain machine.
# Interest star seat sister leg at.
# Scientist provide loss certain. Meet phone common Congress concern.
# Exploring ancient ruins in Machu Picchu was a surreal journey into the heart of Inca civilization.
# I trekked through the Tien Shan mountains in Central Asia, captivated by their beauty.
# ['I', 'trekked', 'through', 'the', 'Tien', 'Shan', 'mountains', 'in', 'Central', 'Asia', ',', 'captivated', 'by', 'their', 'beauty', '.']
# ['O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
# Art enjoy list final break. Land structure always stuff into sense general.
# Until left right window choice. Down kid draw.
# A day at the spa is a luxurious treat for myself.
# Trial upon edge author usually. Then car investment. Run card anyone age but.
# Several purpose hard stop child. Allow name fish your actually lead should. His as turn follow explain something sign drop.
# Officer think compare. Option property evidence behavior walk.
# Ago glass blue news traditional beat.
# Human enjoy idea network eye him traditional. Wall democratic nothing senior event law. Serious guess serve water place off throw.
# Page animal near. Relationship fly today future organization talk. War artist listen save.
# Realize cut easy east according rule value. Employee individual similar despite. Pretty better film machine during bad.
# Even training environmental method off individual game either. Pm these try cup letter traditional bill police. Man imagine agree.
# I marveled at the beauty of the Blue Ridge Mountains in the eastern United States.
# ['I', 'marveled', 'at', 'the', 'beauty', 'of', 'the', 'Blue', 'Ridge', 'Mountains', 'in', 'the', 'eastern', 'United', 'States', '.']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O', 'O']
# Theory page industry maybe smile politics.
# Several draw cultural source recent dream name. Notice serious professional. Mrs bill decision resource drop which reality.
# Process building bad child shoulder game a. Bring reason sense customer moment.
# Police Republican imagine analysis and project as same. Center whole reach hotel.
# The Grand Canyon, carved by the Colorado River, is a geological wonder and a testament to Earth's history.
# Sound hear old similar. Quickly concern song personal. Head and special magazine positive building season.
# Cost rather man option quality truth agent. Sea tax either from beautiful water child take.
# During group professional short. Attention trial interest second require rest. Add some effect model seem dark spend.
# Technology tend score important small between. Data message smile through seat open. As a past indicate song yeah experience.
# Listen record land similar attack hotel. Allow reduce wait energy particularly. Once decide I.
# Deal civil way population huge movement provide threat. Until security fire while nice analysis fund party.
# The Kunlun Mountains stretch across western China.
# ['The', 'Kunlun', 'Mountains', 'stretch', 'across', 'western', 'China', '.']
# ['O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O', 'O', 'O', 'O']
# Condition carry her provide. Rate talk instead also.
# Source pay say main leg whether necessary.
# They never audience meet. Appear region allow administration better light discover.
# Witnessing the mesmerizing Northern Lights dancing across the sky over the Scandinavian Mountains #auroraborealis #mountainmagic
# ['Witnessing', 'the', 'mesmerizing', 'Northern', 'Lights', 'dancing', 'across', 'the', 'sky', 'over', 'the', 'Scandinavian', 'Mountains', '#auroraborealis', '#mountainmagic']
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-MOUNTAIN', 'I-MOUNTAIN', 'O', 'O']
# Consumer join stage. Best likely center they pretty rate work. Item see word dog common high environment.
# Hospital real school cover hotel over. Any training religious without business.
# A brilliant pass from the midfielder sets up a scoring opportunity for the forward.

# %% [markdown]
# ###### Create a new DataFrame to store the processed tokens and NER tags and save the new DataFrame to a CSV file

# %%
new_df = pd.DataFrame({'tokens': tokens_list, 'ner_tags': ner_tags_list})
new_df.to_csv('datas/processed_mountain_dataset.csv', index=False)
